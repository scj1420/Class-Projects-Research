# %% [markdown]
# # Bandits (Volume 2, Sections 17.2-3)
# ## Seong-Eun Cho

# %%
import numpy as np
import time
import scipy.stats as stats

# %%
if np.random.binomial(1, 0.1):
    print("success")
else:
    print("fail")
b = [4,3,2]
b[np.argmin(b)]
# Out:
# fail
# 2

# %%
class Bernoulli_bandits(object):
    """Models the Bernoulli bandit process/solution where one arm is pulled, the results are recorded,
    the next optimal arm (with the largest Gittins index) is then chosen and pulled, and the results
    recorded, and so on for T iterations"""
    
    def __init__(self, Theta, J, K, T, M, Beta):
        """Initialization method.
        
        Accepts:
            Theta: n-vector of success probabilities for each arm (0 indexed)
            J: n-vector of payouts for each arm (0 indexed)
            K: int, number of grid points in [0,J_i] to take each r from
            T: int, number of iterations to repeat the process
            M: int > T, at which to initialize the method compute_R()
            Beta: float, discount factor
            
        Initializes:
            Theta, J, wins, losses, K, T, M, Beta, total_winnings
            (optional): R (vector, if precompute compute_R() in final implementation)
        """
        self.n = len(Theta)
        self.Theta = Theta
        self.J = J
        self.K = K
        self.T = T
        self.M = M
        self.Beta = Beta
        self.wins = np.ones(self.n, dtype=int)
        self.losses = np.ones(self.n, dtype=int)
        self.total_winnings = 0
        self.R = None
        
    def initialize_R(self):
        """Optional method for precomputing compute_R() in final implentation. 
        PRO TIP: Don't use this method until rest of class is completed. After all, 
            'premature optimization is the root of all evil'."""
        R = {}
        for r in np.linspace(0,1,self.K):
            R[r] = self.compute_R(r)
        return R
    
    def pull(self, i):
        """Funtion that models a single pull of an n-armed bandit system.

        Accepts:
            i: index of arm that should be pulled. 

        Updates:
            total_winnings: value won from your pull
            wins[i]: number of successes of arm i
            losses[i]: number of failures of arm i
        """
        if np.random.binomial(1, self.Theta[i]):
            self.wins[i] += 1
            self.total_winnings += self.J[i]
        else:
            self.losses[i] += 1
        
    def compute_R(self, r):
        """Computes R value.

        Inputs:
            M: integer
            r: float

        Returns:
            R_values: array (M+1)x(M+1)
            """
        R = np.zeros((self.M+1,self.M+1))
        for a in range(self.M+1):
            b = self.M - a
            R[a,b] = 1/(1-self.Beta) * max([a/(a+b),r])
        for i in range(self.M-1, 0, -1):
            for a in range(i+1):
                b = i - a
                p1 = a/(a+b) * (1 + self.Beta*R[a+1,b]) + b/(a+b) * self.Beta*R[a,b+1]
                p2 = r/(1-self.Beta)
                R[a,b] = max([p1,p2])
        return R
        
    def gittins(self):
        """ Approximate gittins index to determine the next arm to pull.

        Parameters:
            J: lenth n array of floats (payouts)
            states: nx2 array of states
            M: integer
            K: integer, grid

        Returns:
            values: array of floats, corresponding to the Gittins index of each arm.
        """
        r_values = []
        for a,b in zip(self.wins, self.losses):
            diff = []
            for r in np.linspace(0,1,self.K):
                diff.append(abs(r/(1-self.Beta) - (a/(a+b) * (1 + self.Beta*self.R[r][a+1,b]) + b/(a+b) * self.Beta*self.R[r][a,b+1])))
            r_values.append(np.linspace(0,1,self.K)[np.argmin(diff)])
        return self.J * np.array(r_values)
        
    def simulate(self):
        """simulate multiple bandit pulls
        
        Returns:
            theta_hats: n-array of estimated probabilities
            self.total_winnings: (float) total amount won during play
        """
        self.R = self.initialize_R()
        for t in range(self.T):
            self.pull(np.argmax(self.gittins()))
        theta_hats = self.wins/(self.wins+self.losses)
        return theta_hats, self.total_winnings

# %%
Theta = [0.2,0.5,0.7]
J = [1,1,1]
K = 100
T = 100
M = 105
Beta = 0.9
N = 20
Bandit = Bernoulli_bandits(Theta, J, K, T, M, Beta)
# Testing functionality of pull
'''
for i in range(N):
    Bandit.pull(0)
    Bandit.pull(1)
    Bandit.pull(2)
print(Bandit.wins)
print(Bandit.losses)
print(Bandit.total_winnings)
'''
# Testing functionality of compute_R
print(Bandit.compute_R(0.35))
# Out:
# [[ 0.          3.5         3.5        ...  3.5         3.5
#    3.5       ]
#  [10.          5.32762404  4.01744856 ...  3.5         3.5
#    0.        ]
#  [10.          6.71060486  5.13349643 ...  3.5         0.
#    0.        ]
#  ...
#  [10.          9.90384615  9.80952381 ...  0.          0.
#    0.        ]
#  [10.          9.9047619   0.         ...  0.          0.
#    0.        ]
#  [10.          0.          0.         ...  0.          0.
#    0.        ]]

# %%
# Do not modify the following test case, as it will be used in grading.
Theta = [0.2,0.5,0.7]
J = [1,1,1]
K = 100
T = 100
M = 105
Beta = 0.9
N = 20
for i in range(N):
    print("trial ----------------{}-------------".format(i+1))
    gittins_bandit = Bernoulli_bandits(Theta, J, K, T, M, Beta)
    theta_hat, payout = gittins_bandit.simulate()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print()
# Out:
# trial ----------------1-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.42857143 0.64583333]
# you won: $63
#
# trial ----------------2-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.64285714 0.4       ]
# you won: $63
#
# trial ----------------3-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.33333333 0.68686869]
# you won: $68
#
# trial ----------------4-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.61333333 0.57142857]
# you won: $60
#
# trial ----------------5-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.55319149 0.33333333]
# you won: $53
#
# trial ----------------6-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.35294118 0.63076923]
# you won: $52
#
# trial ----------------7-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.48484848 0.56716418]
# you won: $53
#
# trial ----------------8-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.4        0.69387755]
# you won: $68
#
# trial ----------------9-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.79      ]
# you won: $78
#
# trial ----------------10-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.41666667 0.68888889]
# you won: $65
#
# trial ----------------11-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.44444444 0.64102564]
# you won: $59
#
# trial ----------------12-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.57142857 0.33333333 0.66666667]
# you won: $66
#
# trial ----------------13-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.6        0.66666667]
# you won: $65
#
# trial ----------------14-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.68      ]
# you won: $67
#
# trial ----------------15-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.42857143 0.69791667]
# you won: $68
#
# trial ----------------16-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.77319588]
# you won: $76
#
# trial ----------------17-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.57142857 0.4       ]
# you won: $56
#
# trial ----------------18-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.72727273]
# you won: $72
#
# trial ----------------19-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.33333333 0.60416667]
# you won: $58
#
# trial ----------------20-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.71      ]
# you won: $70

# %% [markdown]
# # Once the previous code is implemented for Bernoulli bandits, create a new class below which implements Thompson Sampling
# ## This should be relatively simple if you implemented Bernoulli bandits correctly. Don't forget to complete all parts of all the problems for full credit, particularly 17.10.

# %%
class Thompson_sampling(Bernoulli_bandits):
    def __init__(self, Theta, J, K, T, M, Beta):
        Bernoulli_bandits.__init__(self, Theta, J, K, T, M, Beta)
        
    def initialize_state(self, state_vector):
        self.wins = state_vector[:,0]
        self.losses = state_vector[:,1]
    # 17.8
    def thompson(self):
        samples = []
        for a,b in zip(self.wins, self.losses):
            samples.append(np.random.beta(a, b))
        return np.argmax(samples)
    # 17.9
    def simulate_thompson(self):
        for t in range(self.T):
            self.pull(self.thompson())
        theta_hats = self.wins/(self.wins+self.losses)
        return theta_hats, self.total_winnings

# %%
# Testing functionality of 17.9
Theta = [0.2,0.5,0.7]
J = [1,1,1]
K = 100
T = 100
M = 105
Beta = 0.9
N = 20
for i in range(N):
    print("trial ----------------{}-------------".format(i+1))
    thompson_bandit = Thompson_sampling(Theta, J, K, T, M, Beta)
    theta_hat, payout = thompson_bandit.simulate_thompson()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print()
# Out:
# trial ----------------1-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.41176471 0.65      ]
# you won: $59
#
# trial ----------------2-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.44444444 0.68888889]
# you won: $65
#
# trial ----------------3-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.23076923 0.47435897 0.53333333]
# you won: $45
#
# trial ----------------4-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.54545455 0.6        0.78666667]
# you won: $74
#
# trial ----------------5-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.42857143 0.75531915]
# you won: $72
#
# trial ----------------6-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.44444444 0.7826087 ]
# you won: $74
#
# trial ----------------7-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.3125     0.5        0.62121212]
# you won: $55
#
# trial ----------------8-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.45454545 0.62337662]
# you won: $57
#
# trial ----------------9-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.44444444 0.79569892]
# you won: $76
#
# trial ----------------10-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.4        0.68292683]
# you won: $62
#
# trial ----------------11-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.22222222 0.33333333 0.71764706]
# you won: $64
#
# trial ----------------12-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.2        0.74157303]
# you won: $70
#
# trial ----------------13-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.65714286 0.671875  ]
# you won: $65
#
# trial ----------------14-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.14285714 0.22222222 0.71111111]
# you won: $64
#
# trial ----------------15-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.25       0.76842105]
# you won: $73
#
# trial ----------------16-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.22222222 0.47058824 0.6875    ]
# you won: $62
#
# trial ----------------17-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.47368421 0.72727273]
# you won: $66
#
# trial ----------------18-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.4        0.73626374]
# you won: $69
#
# trial ----------------19-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.125      0.42105263 0.69620253]
# you won: $61
#
# trial ----------------20-------------
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.41176471 0.6746988 ]
# you won: $61

# %%
# 17.10 with K = 100, M = 105, T = 100
Theta = [0.2,0.5,0.7]
J = [1,1,1]
K = 100
T = 100
M = 105
Beta = 0.9
N = 20
for i in range(N):
    print("trial ----------------{}-------------".format(i+1))
    print("Gittin simulation with K = {}, M = {}:".format(K, M))
    gittin_bandit = Thompson_sampling(Theta, J, K, T, M, Beta)
    t1 = time.time()
    theta_hat, payout = gittin_bandit.simulate()
    t2 = time.time()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print("Simulation time: {}seconds".format(t2-t1))
    print()
    print("Thompson simulation:")
    thompson_bandit = Thompson_sampling(Theta, J, K, T, M, Beta)
    t3 = time.time()
    theta_hat, payout = thompson_bandit.simulate_thompson()
    t4 = time.time()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print("Simulation time: {}seconds".format(t4-t3))
    print()
# Out:
# trial ----------------1-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.41666667 0.78021978]
# you won: $74
# Simulation time: 1.2349801063537598seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.6031746  0.59459459]
# you won: $58
# Simulation time: 0.007215976715087891seconds
#
# trial ----------------2-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.25       0.52083333]
# you won: $50
# Simulation time: 1.2798528671264648seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.2        0.73958333]
# you won: $70
# Simulation time: 0.009247064590454102seconds
#
# trial ----------------3-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.77      ]
# you won: $76
# Simulation time: 1.1654682159423828seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2     0.2     0.65625]
# you won: $62
# Simulation time: 0.005181074142456055seconds
#
# trial ----------------4-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.47916667 0.33333333]
# you won: $46
# Simulation time: 1.2327258586883545seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.64285714 0.64634146]
# you won: $63
# Simulation time: 0.009330987930297852seconds
#
# trial ----------------5-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.42857143 0.5        0.70786517]
# you won: $68
# Simulation time: 1.2187581062316895seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.375      0.38461538 0.61038961]
# you won: $55
# Simulation time: 0.004897117614746094seconds
#
# trial ----------------6-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.69      ]
# you won: $68
# Simulation time: 1.1226708889007568seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.53846154 0.75581395]
# you won: $71
# Simulation time: 0.004789113998413086seconds
#
# trial ----------------7-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.48837209 0.63333333]
# you won: $57
# Simulation time: 1.2187409400939941seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.59183673 0.78846154]
# you won: $68
# Simulation time: 0.00719904899597168seconds
#
# trial ----------------8-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.71      ]
# you won: $70
# Simulation time: 1.148284912109375seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.28571429 0.67021277]
# you won: $63
# Simulation time: 0.003317117691040039seconds
#
# trial ----------------9-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.5        0.66666667]
# you won: $65
# Simulation time: 1.1911799907684326seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.22222222 0.66292135]
# you won: $60
# Simulation time: 0.005589008331298828seconds
#
# trial ----------------10-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.25       0.67708333]
# you won: $65
# Simulation time: 1.1615509986877441seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.42857143 0.73404255]
# you won: $70
# Simulation time: 0.004784822463989258seconds
#
# trial ----------------11-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.69      ]
# you won: $68
# Simulation time: 1.1775438785552979seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.6        0.72972973]
# you won: $68
# Simulation time: 0.00436711311340332seconds
#
# trial ----------------12-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.4        0.66326531]
# you won: $65
# Simulation time: 1.204899787902832seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.42857143 0.70930233]
# you won: $65
# Simulation time: 0.00644993782043457seconds
#
# trial ----------------13-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.56410256 0.65625   ]
# you won: $62
# Simulation time: 1.1673080921173096seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.375      0.6        0.69230769]
# you won: $66
# Simulation time: 0.005742073059082031seconds
#
# trial ----------------14-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.58974359 0.5625    ]
# you won: $57
# Simulation time: 1.1191987991333008seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.2        0.68421053]
# you won: $64
# Simulation time: 0.00481414794921875seconds
#
# trial ----------------15-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.33333333 0.75757576]
# you won: $75
# Simulation time: 1.1705858707427979seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.5        0.78823529]
# you won: $73
# Simulation time: 0.004720926284790039seconds
#
# trial ----------------16-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.72164948]
# you won: $71
# Simulation time: 1.2202200889587402seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.22222222 0.69230769]
# you won: $63
# Simulation time: 0.007590770721435547seconds
#
# trial ----------------17-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.74      ]
# you won: $73
# Simulation time: 1.2406432628631592seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.57142857 0.77011494]
# you won: $74
# Simulation time: 0.004357099533081055seconds
#
# trial ----------------18-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.45263158 0.25      ]
# you won: $43
# Simulation time: 1.198979139328003seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.33333333 0.75268817]
# you won: $71
# Simulation time: 0.0063250064849853516seconds
#
# trial ----------------19-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.63265306 0.4       ]
# you won: $62
# Simulation time: 1.16251802444458seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.22222222 0.42105263 0.64102564]
# you won: $57
# Simulation time: 0.005484104156494141seconds
#
# trial ----------------20-------------
# Gittin simulation with K = 100, M = 105:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.65656566]
# you won: $65
# Simulation time: 1.1442310810089111seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.2        0.71428571]
# you won: $67
# Simulation time: 0.005147218704223633seconds

# %%
# 17.10 with K = 20, M = 22, T = 20
Theta = [0.2,0.5,0.7]
J = [1,1,1]
K = 20
T = 20
M = 22
Beta = 0.9
N = 20
for i in range(N):
    print("trial ----------------{}-------------".format(i+1))
    print("Gittin simulation with K = {}, M = {}:".format(K, M))
    gittin_bandit = Thompson_sampling(Theta, J, K, T, M, Beta)
    t1 = time.time()
    theta_hat, payout = gittin_bandit.simulate()
    t2 = time.time()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print("Simulation time: {}seconds".format(t2-t1))
    print()
    print("Thompson simulation:")
    thompson_bandit = Thompson_sampling(Theta, J, K, T, M, Beta)
    t3 = time.time()
    theta_hat, payout = thompson_bandit.simulate_thompson()
    t4 = time.time()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print("Simulation time: {}seconds".format(t4-t3))
    print()
# Out:
# trial ----------------1-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.33333333 0.73684211]
# you won: $14
# Simulation time: 0.018338918685913086seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.8       ]
# you won: $15
# Simulation time: 0.003566741943359375seconds
#
# trial ----------------2-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.66666667 0.5       ]
# you won: $13
# Simulation time: 0.028355121612548828seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.58333333 0.5       ]
# you won: $10
# Simulation time: 0.001157999038696289seconds
#
# trial ----------------3-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.64705882 0.25      ]
# you won: $10
# Simulation time: 0.028852224349975586seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.33333333 0.6875    ]
# you won: $11
# Simulation time: 0.001386880874633789seconds
#
# trial ----------------4-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.375      0.71428571]
# you won: $11
# Simulation time: 0.02816295623779297seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.625      0.69230769]
# you won: $13
# Simulation time: 0.0012350082397460938seconds
#
# trial ----------------5-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.65      ]
# you won: $12
# Simulation time: 0.019498825073242188seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.58823529 0.4       ]
# you won: $10
# Simulation time: 0.0016677379608154297seconds
#
# trial ----------------6-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.6        0.4       ]
# you won: $10
# Simulation time: 0.021139144897460938seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.42857143 0.5        0.86666667]
# you won: $15
# Simulation time: 0.0015180110931396484seconds
#
# trial ----------------7-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.375      0.57142857]
# you won: $9
# Simulation time: 0.017112016677856445seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.7        0.53846154]
# you won: $12
# Simulation time: 0.0009369850158691406seconds
#
# trial ----------------8-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.42857143 0.55555556 0.33333333]
# you won: $9
# Simulation time: 0.017562150955200195seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.54545455 0.63636364]
# you won: $11
# Simulation time: 0.0009191036224365234seconds
#
# trial ----------------9-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.8       ]
# you won: $15
# Simulation time: 0.017088890075683594seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.2        0.53333333]
# you won: $9
# Simulation time: 0.0010869503021240234seconds
#
# trial ----------------10-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.375      0.6        0.33333333]
# you won: $10
# Simulation time: 0.016973018646240234seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.25       0.58823529]
# you won: $9
# Simulation time: 0.0017490386962890625seconds
#
# trial ----------------11-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.58823529 0.83333333]
# you won: $13
# Simulation time: 0.017001867294311523seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5    0.5    0.6875]
# you won: $13
# Simulation time: 0.0013163089752197266seconds
#
# trial ----------------12-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.375      0.25       0.57142857]
# you won: $9
# Simulation time: 0.0180509090423584seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5  0.75 0.75]
# you won: $15
# Simulation time: 0.001178741455078125seconds
#
# trial ----------------13-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.64705882 0.5       ]
# you won: $12
# Simulation time: 0.026784896850585938seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.78571429]
# you won: $12
# Simulation time: 0.0009438991546630859seconds
#
# trial ----------------14-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.84210526]
# you won: $16
# Simulation time: 0.018321990966796875seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.25       0.77777778]
# you won: $14
# Simulation time: 0.0011217594146728516seconds
#
# trial ----------------15-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.9       ]
# you won: $17
# Simulation time: 0.020774126052856445seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.66666667 0.6       ]
# you won: $13
# Simulation time: 0.0014879703521728516seconds
#
# trial ----------------16-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.41666667 0.54545455 0.33333333]
# you won: $9
# Simulation time: 0.017444133758544922seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.44444444 0.75      ]
# you won: $11
# Simulation time: 0.0010461807250976562seconds
#
# trial ----------------17-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.84210526]
# you won: $16
# Simulation time: 0.017824888229370117seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.63157895 0.5       ]
# you won: $12
# Simulation time: 0.0009849071502685547seconds
#
# trial ----------------18-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.36363636 0.44444444]
# you won: $7
# Simulation time: 0.017037153244018555seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.33333333 0.8       ]
# you won: $12
# Simulation time: 0.0010421276092529297seconds
#
# trial ----------------19-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.42857143 0.33333333 0.5       ]
# you won: $9
# Simulation time: 0.016972064971923828seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.33333333 0.63157895]
# you won: $12
# Simulation time: 0.0009279251098632812seconds
#
# trial ----------------20-------------
# Gittin simulation with K = 20, M = 22:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.4375     0.33333333]
# you won: $7
# Simulation time: 0.01718878746032715seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.42857143 0.57142857 0.66666667]
# you won: $12
# Simulation time: 0.0010349750518798828seconds

# %%
# 17.10 with K = 50, M = 55, T = 10
Theta = [0.2,0.5,0.7]
J = [1,1,1]
K = 50
T = 10
M = 55
Beta = 0.9
N = 20
for i in range(N):
    print("trial ----------------{}-------------".format(i+1))
    print("Gittin simulation with K = {}, M = {}:".format(K, M))
    gittin_bandit = Thompson_sampling(Theta, J, K, T, M, Beta)
    t1 = time.time()
    theta_hat, payout = gittin_bandit.simulate()
    t2 = time.time()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print("Simulation time: {}seconds".format(t2-t1))
    print()
    print("Thompson simulation:")
    thompson_bandit = Thompson_sampling(Theta, J, K, T, M, Beta)
    t3 = time.time()
    theta_hat, payout = thompson_bandit.simulate_thompson()
    t4 = time.time()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print("Simulation time: {}seconds".format(t4-t3))
    print()
# Out:
# trial ----------------1-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25 0.25 0.5 ]
# you won: $3
# Simulation time: 0.16497588157653809seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.25       0.88888889]
# you won: $7
# Simulation time: 0.0004868507385253906seconds
#
# trial ----------------2-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.25       0.66666667]
# you won: $4
# Simulation time: 0.14420700073242188seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.6        0.75      ]
# you won: $7
# Simulation time: 0.0004990100860595703seconds
#
# trial ----------------3-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.6       ]
# you won: $5
# Simulation time: 0.1595780849456787seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.25       0.57142857]
# you won: $3
# Simulation time: 0.0006849765777587891seconds
#
# trial ----------------4-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.85714286]
# you won: $7
# Simulation time: 0.1621079444885254seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.16666667 0.83333333]
# you won: $4
# Simulation time: 0.0005939006805419922seconds
#
# trial ----------------5-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.25       0.33333333]
# you won: $2
# Simulation time: 0.17121601104736328seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.33333333 0.66666667]
# you won: $5
# Simulation time: 0.0009748935699462891seconds
#
# trial ----------------6-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.7       ]
# you won: $6
# Simulation time: 0.1748640537261963seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.5        0.66666667]
# you won: $5
# Simulation time: 0.0007398128509521484seconds
#
# trial ----------------7-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.6       ]
# you won: $5
# Simulation time: 0.16086196899414062seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.4        0.5       ]
# you won: $3
# Simulation time: 0.0005290508270263672seconds
#
# trial ----------------8-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25 0.25 0.75]
# you won: $5
# Simulation time: 0.1456608772277832seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.66666667 0.7       ]
# you won: $7
# Simulation time: 0.0005738735198974609seconds
#
# trial ----------------9-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.7       ]
# you won: $6
# Simulation time: 0.1608269214630127seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.6        0.33333333]
# you won: $3
# Simulation time: 0.0011892318725585938seconds
#
# trial ----------------10-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.6        0.33333333]
# you won: $5
# Simulation time: 0.15336298942565918seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.66666667 0.4        0.75      ]
# you won: $7
# Simulation time: 0.0005321502685546875seconds
#
# trial ----------------11-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.8       ]
# you won: $7
# Simulation time: 0.1508960723876953seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25 0.5  0.6 ]
# you won: $5
# Simulation time: 0.0004458427429199219seconds
#
# trial ----------------12-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25  0.375 0.5  ]
# you won: $3
# Simulation time: 0.15977191925048828seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.5        0.33333333]
# you won: $4
# Simulation time: 0.0013530254364013672seconds
#
# trial ----------------13-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.55555556 0.75      ]
# you won: $6
# Simulation time: 0.16216397285461426seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.4        0.625     ]
# you won: $5
# Simulation time: 0.0012240409851074219seconds
#
# trial ----------------14-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.6       ]
# you won: $5
# Simulation time: 0.18298912048339844seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.6        0.875     ]
# you won: $8
# Simulation time: 0.001796722412109375seconds
#
# trial ----------------15-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4 0.5 0.6]
# you won: $5
# Simulation time: 0.22082114219665527seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.42857143 0.5       ]
# you won: $4
# Simulation time: 0.000637054443359375seconds
#
# trial ----------------16-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.5       ]
# you won: $4
# Simulation time: 0.18361592292785645seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.16666667 0.25      ]
# you won: $1
# Simulation time: 0.0006551742553710938seconds
#
# trial ----------------17-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.25      ]
# you won: $2
# Simulation time: 0.23480486869812012seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.4        0.71428571]
# you won: $5
# Simulation time: 0.0008130073547363281seconds
#
# trial ----------------18-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.6        0.33333333]
# you won: $5
# Simulation time: 0.29543399810791016seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.6        0.4       ]
# you won: $4
# Simulation time: 0.0015492439270019531seconds
#
# trial ----------------19-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.63636364 0.5       ]
# you won: $6
# Simulation time: 0.1900491714477539seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.25       0.77777778]
# you won: $6
# Simulation time: 0.0006971359252929688seconds
#
# trial ----------------20-------------
# Gittin simulation with K = 50, M = 55:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.5        0.44444444 0.33333333]
# you won: $4
# Simulation time: 0.18173694610595703seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.33333333 0.5       ]
# you won: $3
# Simulation time: 0.002251863479614258seconds

# %%
# 17.10 with K = 200, M = 210, T = 200
Theta = [0.2,0.5,0.7]
J = [1,1,1]
K = 200
T = 200
M = 210
Beta = 0.9
N = 20
for i in range(N):
    print("trial ----------------{}-------------".format(i+1))
    print("Gittin simulation with K = {}, M = {}:".format(K, M))
    gittin_bandit = Thompson_sampling(Theta, J, K, T, M, Beta)
    t1 = time.time()
    theta_hat, payout = gittin_bandit.simulate()
    t2 = time.time()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print("Simulation time: {}seconds".format(t2-t1))
    print()
    print("Thompson simulation:")
    thompson_bandit = Thompson_sampling(Theta, J, K, T, M, Beta)
    t3 = time.time()
    theta_hat, payout = thompson_bandit.simulate_thompson()
    t4 = time.time()
    print("true probability: {}\nestimated probability: {}".format(Theta, theta_hat))
    print("you won: ${}".format(payout))
    print("Simulation time: {}seconds".format(t4-t3))
    print()
# Out:
# trial ----------------1-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.33333333 0.65656566]
# you won: $130
# Simulation time: 8.737001895904541seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.14285714 0.578125   0.7037037 ]
# you won: $130
# Simulation time: 0.009381294250488281seconds
#
# trial ----------------2-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.25       0.69191919]
# you won: $136
# Simulation time: 8.767350196838379seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.35      0.4       0.6746988]
# you won: $124
# Simulation time: 0.01355290412902832seconds
#
# trial ----------------3-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.475      0.69135802]
# you won: $129
# Simulation time: 9.223623037338257seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.22222222 0.52941176 0.66871166]
# you won: $126
# Simulation time: 0.015002965927124023seconds
#
# trial ----------------4-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.695     ]
# you won: $138
# Simulation time: 10.109551191329956seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.41666667 0.62765957]
# you won: $121
# Simulation time: 0.010807037353515625seconds
#
# trial ----------------5-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.35714286 0.74213836]
# you won: $131
# Simulation time: 9.11075210571289seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.5        0.73255814]
# you won: $138
# Simulation time: 0.009405136108398438seconds
#
# trial ----------------6-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.41666667 0.25       0.70526316]
# you won: $137
# Simulation time: 9.573004961013794seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.27272727 0.475      0.67741935]
# you won: $124
# Simulation time: 0.009776115417480469seconds
#
# trial ----------------7-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.69849246]
# you won: $139
# Simulation time: 8.67190408706665seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.6        0.69426752]
# you won: $133
# Simulation time: 0.009595870971679688seconds
#
# trial ----------------8-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.2        0.65816327]
# you won: $128
# Simulation time: 8.896290063858032seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.60606061 0.66467066]
# you won: $129
# Simulation time: 0.012771129608154297seconds
#
# trial ----------------9-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.41836735 0.2       ]
# you won: $81
# Simulation time: 9.20553708076477seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.57142857 0.70886076]
# you won: $134
# Simulation time: 0.0074710845947265625seconds
#
# trial ----------------10-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.745     ]
# you won: $148
# Simulation time: 9.161057233810425seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.5        0.7150838 ]
# you won: $137
# Simulation time: 0.015506982803344727seconds
#
# trial ----------------11-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.735     ]
# you won: $146
# Simulation time: 9.129981994628906seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.16666667 0.44       0.68571429]
# you won: $129
# Simulation time: 0.012490987777709961seconds
#
# trial ----------------12-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.7       ]
# you won: $139
# Simulation time: 9.682410955429077seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.14285714 0.33333333 0.7253886 ]
# you won: $140
# Simulation time: 0.005067110061645508seconds
#
# trial ----------------13-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.4        0.33333333 0.74242424]
# you won: $147
# Simulation time: 9.104446172714233seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.14285714 0.33333333 0.73056995]
# you won: $141
# Simulation time: 0.009508132934570312seconds
#
# trial ----------------14-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.58823529 0.7311828 ]
# you won: $144
# Simulation time: 8.754684925079346seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.3    0.4375 0.65  ]
# you won: $124
# Simulation time: 0.009810209274291992seconds
#
# trial ----------------15-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.4        0.7020202 ]
# you won: $139
# Simulation time: 8.55324912071228seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.51219512 0.66666667]
# you won: $124
# Simulation time: 0.019225120544433594seconds
#
# trial ----------------16-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.66      ]
# you won: $131
# Simulation time: 8.573578119277954seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.22222222 0.47222222 0.67701863]
# you won: $125
# Simulation time: 0.010303258895874023seconds
#
# trial ----------------17-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.70050761]
# you won: $139
# Simulation time: 8.753298997879028seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.2        0.5942029  0.71969697]
# you won: $134
# Simulation time: 0.01054692268371582seconds
#
# trial ----------------18-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.72361809]
# you won: $144
# Simulation time: 8.510417938232422seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.28571429 0.57692308 0.68027211]
# you won: $129
# Simulation time: 0.010082006454467773seconds
#
# trial ----------------19-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.5        0.66321244]
# you won: $131
# Simulation time: 8.688431978225708seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.3        0.47368421 0.67231638]
# you won: $128
# Simulation time: 0.009825944900512695seconds
#
# trial ----------------20-------------
# Gittin simulation with K = 200, M = 210:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.33333333 0.33333333 0.75      ]
# you won: $149
# Simulation time: 8.75161099433899seconds
#
# Thompson simulation:
# true probability: [0.2, 0.5, 0.7]
# estimated probability: [0.25       0.55172414 0.72189349]
# you won: $137
# Simulation time: 0.00960087776184082seconds

# %% [markdown]
# # Feedback
# 10/10: Looks great!
