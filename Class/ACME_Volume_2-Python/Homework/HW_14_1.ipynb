# %% [markdown]
# # Homework for Volume 2, Section 14.1
# ## Seong-Eun Cho

# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %% [markdown]
# ## Problem 14.3

# %%
# your code here, per problem
x1 = np.linspace(-1, 1, 200)
y1 = np.linspace(-1, 1, 200)
X1,Y1 = np.meshgrid(x1,y1)
x2 = np.linspace(-10, 10, 200)
y2 = np.linspace(-10, 10, 200)
X2, Y2 = np.meshgrid(x2,y2)
# Problem (i)
h1 = lambda x,y: x**3 + x**2 - y**2
# Problem (ii)
h2 = lambda x,y: x**3 - x**2 - y**2
# Problem (iii)
h3 = lambda x,y: x**3 - y**2
# Problem (iv)
h4 = lambda x,y: np.sqrt(x**2 - y**2)
# Problem (v)
h5 = lambda x,y: np.sqrt(x**2*y)

plt.contour(X1, Y1, h1(X1,Y1), levels=[0])
plt.gca().set_aspect('equal', 'box')
plt.show()

plt.contour(X2, Y2, h2(X2,Y2), levels=[0])
plt.gca().set_aspect('equal', 'box')
plt.show()

plt.contour(X1, Y1, h3(X1,Y1), levels=[0])
plt.gca().set_aspect('equal', 'box')
plt.show()

fig = plt.figure()
ax = fig.gca(projection='3d')
surf1 = ax.plot_surface(X, Y, h4(X,Y))
surf2 = ax.plot_surface(X, Y, -h4(X,Y))
plt.show()

plt.contour(X1, Y1, h4(X1,Y1))
plt.gca().set_aspect('equal', 'box')
plt.show()

fig = plt.figure()
ax = fig.gca(projection='3d')
surf3 = ax.plot_surface(X, Y, h5(X,Y))
surf4 = ax.plot_surface(X, Y, -h5(X,Y))
plt.show()

plt.contour(X1, Y1, h5(X1,Y1))
plt.gca().set_aspect('equal', 'box')
plt.show()
# Out:
# /Users/Seong-EunCho/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:15: RuntimeWarning: invalid value encountered in sqrt
# /Users/Seong-EunCho/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:17: RuntimeWarning: invalid value encountered in sqrt
